# %%
# conda environment tf-gpu

# %%
from sklearn.model_selection import train_test_split
from os import listdir
from os.path import isfile, join
from scipy.io import savemat, loadmat
from sklearn.metrics import confusion_matrix

# import mat73
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns

import os
import re
import random
import einops
from scipy.io import loadmat
from pathlib import Path
from PIL import Image
# import PIL.Image as Image

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# the following import is required for matplotlib < 3.2:
from mpl_toolkits.mplot3d import Axes3D  # noqa
import matplotlib
# matplotlib.use('Agg') # use a non-interactive backend such as Agg (for PNGs), PDF, SVG or PS.

# %%
# using CNN with TensorFlow core
import tensorflow as tf
from tensorflow import keras
from keras import Model, layers, models
print("TensorFlow version:", tf.__version__)
# from tensorflow.keras import datasets, layers, models
# from tensorflow.keras.layers import Dense, Flatten, Conv2D
import matplotlib.pyplot as plt
import collections
# TensorFlow version: 2.13.0
# Out:
# TensorFlow version: 2.17.0

# %%
# tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
def get_available_device():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

# %%
print(get_available_device())
# Out:
# ['/device:CPU:0']

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # Configure video data

# %%
path = '../image dataset/'
files = os.listdir(path)
sub_num = 1
files_head = [f for f in files if re.match(r'^sub' + str(sub_num) + '.*_1\.jpg$', f)]

# %%
def get_class(fname):
  return fname.split('_')[1]

# %%
def get_sub(fname):
  return fname.split('_')[0]

# %%
def integrate_video(fname, path):
    img = Image.open(path + fname).convert('CMYK')
    data = np.expand_dims(np.asarray(img), axis=0)
    for i in range(1, 7):
        fn = fname.replace('_1.jpg',f'_{i+1}.jpg')
        img_ = Image.open(path + fn).convert('CMYK')
        arr = np.expand_dims(np.asarray(img_), axis=0)
        data = np.concatenate((data, arr), axis=0)  # shape: (frame_num, width, height, channel)
    return data

# %%
def save_video(files, path):
    ds = []
    sub_dict = []
    class_dict = []
    for f in files:
        data = integrate_video(f, path)
        sub = get_sub(f)
        cls = get_class(f)
        ds.append(data)
        sub_dict.append(sub)
        class_dict.append(cls)

    return ds, sub_dict, class_dict

# %%
data, sub_dict, class_dict = save_video(files_head, path)

# %%
data[0].shape
# Out:
# (7, 369, 433, 4)

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize

# Generate synthetic data as example (7 frames, 369x433 size, 4 channels)
original_data = data[0]

# Resize the data to (7, 32, 32, 4)
resized_data = np.zeros((7, 32, 32, 4))
for i in range(original_data.shape[0]):
    resized_data[i] = resize(original_data[i], (32, 32, 4), anti_aliasing=True)

# Plot the original and resized figure for the first frame
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Display the original frame (only first channel for visualization)
axes[0].imshow(original_data[4, :, :, :])
axes[0].set_title("Original Frame (First Channel)")
axes[0].axis('off')

# Display the resized frame (only first channel for visualization)
axes[1].imshow(resized_data[4, :, :, :])
axes[1].set_title("Resized Frame (First Channel)")
axes[1].axis('off')

plt.tight_layout()
plt.show()

def resize_image_size(data, target_size=(7, 32, 32, 4)):
    resized_data = []
    for one_video in data:
        resized_one_video = np.zeros(target_size)
        for i in range (one_video.shape[0]):
            resized_one_video[i] = resize(one_video[i], (target_size[1], target_size[2], target_size[3]), anti_aliasing=True)
        resized_data.append(resized_one_video)
    
    return resized_data

data = resize_image_size(data)

# %%
data[260].shape
# Out:
# (7, 32, 32, 4)

# %% [markdown]
# Load image: read as video frames (Tensorflow tutorial)

# %%
def get_files_per_class(files):
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %%
files_for_class = get_files_per_class(files)
classes = list(files_for_class.keys())

# %%
print('Num classes:', len(classes))
print('Num videos for class[0]:', len(files_for_class[classes[0]]))
# Out:
# Num classes: 6
# Num videos for class[0]: 2205

# %%
def select_subset_of_classes(files_for_class, classes, files_per_class):
  """ 
    Use for 3-class/in-subclass comparison
  """
  files_subset = dict()

  for class_name in classes:
    class_files = files_for_class[class_name]
    files_subset[class_name] = class_files[:files_per_class]

  return files_subset

# %%
NUM_CLASSES = 2
FILES_PER_CLASS = 90   # 270 trials for each sub, 45 trials for each class per sub, 315 trials for each class in general

# %%
files_subset = select_subset_of_classes(files_for_class, classes[:NUM_CLASSES], FILES_PER_CLASS)
list(files_subset.keys())
# Out:
# ['back', 'down']

# %%
# load data depends on subject and class

# %%
def get_files_per_sub_per_class(files):
  files_for_sub_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    sub_num = get_sub(fname)
    files_for_sub_for_class[(sub_num, class_name)].append(fname)
  return files_for_sub_for_class

# %%
files_for_sub_for_class = get_files_per_sub_per_class(files)
classes_2stage = list(files_for_sub_for_class.keys())

# %%
print('Num classes:', len(classes_2stage))
print('Num videos for class[0]:', len(files_for_sub_for_class[classes_2stage[0]]))
# Out:
# Num classes: 42
# Num videos for class[0]: 315

# %% [markdown]
# select random train/test dataset

# %%
trial_dict = {'front':0, 'back':1, 'left':2, 'right':3, 'up':4, 'down':5}
label = [trial_dict[x] for x in class_dict]

# %%
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.33, random_state=42)

# %%
print(x_train[0].shape)
print(len(x_train))
print(len(y_train))
# Out:
# (7, 32, 32, 4)
# 180
# 180

# %%
x_train = [tf.convert_to_tensor(item) for item in x_train]
x_test = [tf.convert_to_tensor(item) for item in x_test]
y_train = [tf.convert_to_tensor(item) for item in y_train]
y_test = [tf.convert_to_tensor(item) for item in y_test]

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %%
# batch_size = 8
# train_ds = train_ds.batch(batch_size)
# test_ds = test_ds.batch(batch_size)

# %%
# test_batches = tf.data.experimental.cardinality(test_ds) # return the num of test batches
# val_ds = test_ds.take(test_batches//3)
# test_ds = test_ds.skip(test_batches//3)

# %% [markdown]
# ## RCNN Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model


class VGGStyleCNN(Model):
    """
    VGG-style CNN based on configuration D.
    """
    def __init__(self, img_size, n_colors):
        super(VGGStyleCNN, self).__init__()
        self.conv1 = layers.Conv2D(img_size, (3, 3), activation='relu', padding='same')
        self.pool1 = layers.MaxPooling2D((2, 2))

        self.conv2 = layers.Conv2D(img_size * 2, (3, 3), activation='relu', padding='same')
        self.pool2 = layers.MaxPooling2D((2, 2))
        
        self.conv3 = layers.Conv2D(img_size * 4, (3, 3), activation='relu', padding='same')
        self.pool3 = layers.MaxPooling2D((2, 2))

        self.flatten = layers.Flatten()

    def call(self, inputs):
        print(f"Input to each ConvNet: {inputs.shape}")
        x = self.conv1(inputs)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.pool2(x)

        x = self.conv3(x)
        x = self.pool3(x)

        x = self.flatten(x)
        print(f"ConvNet output shape: {x.shape}")
        return x


class MixedLSTM1DConv(Model):
    """
    Mixed LSTM/1D-Conv network.
    """
    def __init__(self, input_shape, n_timewin, n_classes, img_size, n_colors):
        super(MixedLSTM1DConv, self).__init__()
        self.n_timewin = n_timewin
        
        # Shared CNN
        self.cnn = VGGStyleCNN(img_size, n_colors)

        # 1D Convolution for short-term temporal patterns
        self.conv1d = layers.Conv1D(filters=32, kernel_size=3, activation='relu') # 64
        self.flatten1d = layers.Flatten()

        # LSTM for long-term temporal dependencies
        self.lstm = layers.LSTM(units=32, activation='tanh', recurrent_activation='sigmoid')

        # Fully connected layers
        self.dropout1 = layers.Dropout(0.5)
        self.fc1 = layers.Dense(units=128, activation='relu')
        self.dropout2 = layers.Dropout(0.5)
        self.output_layer = layers.Dense(n_classes, activation='softmax')

    def call(self, inputs):
        # Process each time window frame through the shared CNN
        # print(f"Input shape: {inputs.shape}")
        cnn_outputs = [self.cnn(inputs[:, i, :, :, :]) for i in range(self.n_timewin)]
        # print(f"Shape after ConvNet: {len(cnn_outputs)}*{cnn_outputs[0].shape}")

        # Reshape the sequence
        lstm_in = tf.stack(cnn_outputs, axis=1)  # now: (batch_size, n_timewin, features)
        # conv1d_in = tf.transpose(lstm_in, perm=[0, 2, 1]) # should be (batch_size, features, n_timewin)
        # print(f"Reshaped to feed Conv1D: {conv1d_in.shape}")
        # print(f"Reshaped to feed LSTM: {lstm_in.shape}")

        # 1D Convolution for temporal patterns
        conv1d_out = self.conv1d(lstm_in)
        # print(f"Shape after Conv1D: {conv1d_out.shape}")
        conv1d_out = self.flatten1d(conv1d_out)
        # print(f"Flattened to combine with LSTM: {conv1d_out.shape}")
        # LSTM for long-term dependencies
        lstm_out = self.lstm(lstm_in)
        # print(f"Shape after LSTM: {lstm_out.shape}")

        # Merge 1D-Conv and LSTM outputs
        merged = tf.concat([conv1d_out, lstm_out], axis=-1)
        # print(f"Merged to feed FC: {merged.shape}")
        # Fully connected layers
        x = self.dropout1(merged)
        x = self.fc1(x)
        x = self.dropout2(x)
        output = self.output_layer(x)
        # print(f"Output shape: {output.shape}")
        return output


# Example usage
batch_size = 10 # 10
n_epochs = 200 # 60
input_shape = (batch_size, 7, 32, 32, 4)
n_timewin = 7
n_classes = 6
img_size = 32
n_colors = 4

# Create the model instance
model = MixedLSTM1DConv(input_shape, n_timewin, n_classes, img_size, n_colors)

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
x_train_tmp = [tensor.numpy() for tensor in x_train]
x_train_ndarray = np.stack(x_train_tmp, axis=0)
print(x_train_ndarray.shape)
y_train_ndarray = np.array([tensor.numpy() for tensor in y_train])

x_test_tmp = [tensor.numpy() for tensor in x_test]
x_test_ndarray = np.stack(x_test_tmp, axis=0)
print(x_test_ndarray.shape)
y_test_ndarray = np.array([tensor.numpy() for tensor in y_test])
# Out:
# (180, 7, 32, 32, 4)
# (90, 7, 32, 32, 4)

# %%
# checkpoint_path = "./sub5_training_stride1_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)
checkpoint_path = "./rcnn/sub"+str(sub_num)+"_training/cp.weights.h5"  # Change the file extension
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True, # save the entire model or weights only
                                                 verbose=1,
                                                 monitor='val_accuracy',
                                                 mode='max',  # max for acc, min for loss
                                                 save_best_only=True)
# history = model.fit(x = train_ds,
#                     epochs = 60,
#                     validation_data = val_ds,
#                     callbacks=[cp_callback])
history = model.fit(x=x_train_ndarray, y=y_train_ndarray, epochs=n_epochs, batch_size=batch_size, verbose=1, validation_split=0.1, callbacks=[cp_callback])
# Out:
# Epoch 1/200
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2208 - loss: 1.7959Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
# Input to each ConvNet: (None, 32, 32, 4)
# ConvNet output shape: (None, 2048)
#
# Epoch 1: val_accuracy improved from -inf to 0.16667, saving model to ./rcnn/sub1_training/cp.weights.h5
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.2155 - loss: 1.7959 - val_accuracy: 0.1667 - val_loss: 1.8529
# Epoch 2/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2549 - loss: 1.7628
# Epoch 2: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2390 - loss: 1.7691 - val_accuracy: 0.1667 - val_loss: 1.8661
# Epoch 3/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2166 - loss: 1.7757
# Epoch 3: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2124 - loss: 1.7760 - val_accuracy: 0.1667 - val_loss: 1.8494
# Epoch 4/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2347 - loss: 1.7805
# Epoch 4: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2248 - loss: 1.7799 - val_accuracy: 0.1667 - val_loss: 1.8421
# Epoch 5/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1796 - loss: 1.7770
# Epoch 5: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1831 - loss: 1.7766 - val_accuracy: 0.1667 - val_loss: 1.8521
# Epoch 6/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2050 - loss: 1.7805
# Epoch 6: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2041 - loss: 1.7767 - val_accuracy: 0.1667 - val_loss: 1.8682
# Epoch 7/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1947 - loss: 1.7556
# Epoch 7: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2027 - loss: 1.7577 - val_accuracy: 0.1111 - val_loss: 1.8722
# Epoch 8/200
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2030 - loss: 1.7920
# Epoch 8: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2091 - loss: 1.7885 - val_accuracy: 0.1667 - val_loss: 1.8534
# Epoch 9/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2312 - loss: 1.7453
# Epoch 9: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2263 - loss: 1.7490 - val_accuracy: 0.1667 - val_loss: 1.8557
# Epoch 10/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1804 - loss: 1.7707
# Epoch 10: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1862 - loss: 1.7672 - val_accuracy: 0.1667 - val_loss: 1.8544
# Epoch 11/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2521 - loss: 1.7374
# Epoch 11: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2557 - loss: 1.7389 - val_accuracy: 0.1111 - val_loss: 1.8441
# Epoch 12/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3743 - loss: 1.7333
# Epoch 12: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3666 - loss: 1.7359 - val_accuracy: 0.1111 - val_loss: 1.8557
# Epoch 13/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4104 - loss: 1.7309
# Epoch 13: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4015 - loss: 1.7305 - val_accuracy: 0.1111 - val_loss: 1.8749
# Epoch 14/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3713 - loss: 1.7310
# Epoch 14: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3717 - loss: 1.7308 - val_accuracy: 0.1111 - val_loss: 1.8406
# Epoch 15/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4232 - loss: 1.7065
# Epoch 15: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4319 - loss: 1.7079 - val_accuracy: 0.1111 - val_loss: 1.8860
# Epoch 16/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4297 - loss: 1.6758
# Epoch 16: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3928 - loss: 1.6819 - val_accuracy: 0.1111 - val_loss: 1.8582
# Epoch 17/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3161 - loss: 1.6732
# Epoch 17: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3057 - loss: 1.6742 - val_accuracy: 0.1667 - val_loss: 1.8832
# Epoch 18/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4524 - loss: 1.6383
# Epoch 18: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4400 - loss: 1.6392 - val_accuracy: 0.1667 - val_loss: 1.9156
# Epoch 19/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3673 - loss: 1.6130
# Epoch 19: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3758 - loss: 1.6136 - val_accuracy: 0.1667 - val_loss: 1.9541
# Epoch 20/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4733 - loss: 1.5621
# Epoch 20: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4703 - loss: 1.5639 - val_accuracy: 0.1111 - val_loss: 1.8998
# Epoch 21/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5614 - loss: 1.5097
# Epoch 21: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5436 - loss: 1.5124 - val_accuracy: 0.1111 - val_loss: 2.0012
# Epoch 22/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5315 - loss: 1.4901
# Epoch 22: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5438 - loss: 1.4812 - val_accuracy: 0.1111 - val_loss: 1.9637
# Epoch 23/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5193 - loss: 1.4182
# Epoch 23: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5136 - loss: 1.4230 - val_accuracy: 0.1111 - val_loss: 1.8786
# Epoch 24/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5226 - loss: 1.3779
# Epoch 24: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5376 - loss: 1.3698 - val_accuracy: 0.1667 - val_loss: 2.1609
# Epoch 25/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6639 - loss: 1.2465
# Epoch 25: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6528 - loss: 1.2498 - val_accuracy: 0.1111 - val_loss: 1.9626
# Epoch 26/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6163 - loss: 1.2369
# Epoch 26: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6123 - loss: 1.2282 - val_accuracy: 0.1667 - val_loss: 2.1507
# Epoch 27/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6150 - loss: 1.1305
# Epoch 27: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6370 - loss: 1.1161 - val_accuracy: 0.1667 - val_loss: 2.0671
# Epoch 28/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6303 - loss: 1.0684
# Epoch 28: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6479 - loss: 1.0587 - val_accuracy: 0.1667 - val_loss: 2.2630
# Epoch 29/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7016 - loss: 0.9782
# Epoch 29: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7165 - loss: 0.9699 - val_accuracy: 0.1111 - val_loss: 2.2075
# Epoch 30/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7718 - loss: 0.8565
# Epoch 30: val_accuracy improved from 0.16667 to 0.22222, saving model to ./rcnn/sub1_training/cp.weights.h5
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7657 - loss: 0.8622 - val_accuracy: 0.2222 - val_loss: 2.2803
# Epoch 31/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7816 - loss: 0.7811
# Epoch 31: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7842 - loss: 0.7826 - val_accuracy: 0.1667 - val_loss: 2.5029
# Epoch 32/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8922 - loss: 0.6766
# Epoch 32: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8744 - loss: 0.6929 - val_accuracy: 0.1111 - val_loss: 2.5704
# Epoch 33/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8171 - loss: 0.6127
# Epoch 33: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8234 - loss: 0.6165 - val_accuracy: 0.1667 - val_loss: 2.4691
# Epoch 34/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8891 - loss: 0.5423
# Epoch 34: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8890 - loss: 0.5469 - val_accuracy: 0.1667 - val_loss: 2.7706
# Epoch 35/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8945 - loss: 0.5114
# Epoch 35: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9023 - loss: 0.5107 - val_accuracy: 0.1111 - val_loss: 2.7691
# Epoch 36/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8469 - loss: 0.5347
# Epoch 36: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8522 - loss: 0.5293 - val_accuracy: 0.1667 - val_loss: 2.9021
# Epoch 37/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9669 - loss: 0.4305
# Epoch 37: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9585 - loss: 0.4251 - val_accuracy: 0.1667 - val_loss: 2.7298
# Epoch 38/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9719 - loss: 0.3068
# Epoch 38: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9651 - loss: 0.3224 - val_accuracy: 0.1667 - val_loss: 2.9641
# Epoch 39/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9162 - loss: 0.3779
# Epoch 39: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9186 - loss: 0.3712 - val_accuracy: 0.1111 - val_loss: 3.0264
# Epoch 40/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9657 - loss: 0.3006
# Epoch 40: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9630 - loss: 0.3123 - val_accuracy: 0.2222 - val_loss: 2.8886
# Epoch 41/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9787 - loss: 0.2952
# Epoch 41: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9796 - loss: 0.2925 - val_accuracy: 0.1667 - val_loss: 3.0798
# Epoch 42/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9696 - loss: 0.2655
# Epoch 42: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9727 - loss: 0.2639 - val_accuracy: 0.1667 - val_loss: 3.2758
# Epoch 43/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9497 - loss: 0.2519
# Epoch 43: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9547 - loss: 0.2450 - val_accuracy: 0.1667 - val_loss: 3.0401
# Epoch 44/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1609
# Epoch 44: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1677 - val_accuracy: 0.1667 - val_loss: 3.1509
# Epoch 45/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.1842
# Epoch 45: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - loss: 0.1809 - val_accuracy: 0.1667 - val_loss: 3.3089
# Epoch 46/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9856 - loss: 0.1889
# Epoch 46: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9806 - loss: 0.1925 - val_accuracy: 0.2222 - val_loss: 3.3445
# Epoch 47/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1349
# Epoch 47: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1353 - val_accuracy: 0.1667 - val_loss: 3.3564
# Epoch 48/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1104
# Epoch 48: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1124 - val_accuracy: 0.1667 - val_loss: 3.4488
# Epoch 49/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0953
# Epoch 49: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0939 - val_accuracy: 0.1667 - val_loss: 3.5903
# Epoch 50/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0669
# Epoch 50: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 0.1667 - val_loss: 3.6813
# Epoch 51/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0848
# Epoch 51: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0816 - val_accuracy: 0.1667 - val_loss: 3.7643
# Epoch 52/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0690
# Epoch 52: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0685 - val_accuracy: 0.1667 - val_loss: 3.7876
# Epoch 53/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0541
# Epoch 53: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0545 - val_accuracy: 0.1667 - val_loss: 3.8423
# Epoch 54/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0610
# Epoch 54: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0591 - val_accuracy: 0.1667 - val_loss: 3.9407
# Epoch 55/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0418
# Epoch 55: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.1667 - val_loss: 3.8965
# Epoch 56/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0423
# Epoch 56: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0421 - val_accuracy: 0.1667 - val_loss: 3.9448
# Epoch 57/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0392
# Epoch 57: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.1667 - val_loss: 4.1321
# Epoch 58/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0399
# Epoch 58: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0394 - val_accuracy: 0.1667 - val_loss: 4.1591
# Epoch 59/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0329
# Epoch 59: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0329 - val_accuracy: 0.1667 - val_loss: 4.1662
# Epoch 60/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0290
# Epoch 60: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0291 - val_accuracy: 0.1667 - val_loss: 4.2003
# Epoch 61/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0255
# Epoch 61: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.1667 - val_loss: 4.2618
# Epoch 62/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 62: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 0.1667 - val_loss: 4.2803
# Epoch 63/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0246
# Epoch 63: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 0.1667 - val_loss: 4.3937
# Epoch 64/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 64: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.1667 - val_loss: 4.3991
# Epoch 65/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0223
# Epoch 65: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.1667 - val_loss: 4.3347
# Epoch 66/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0196
# Epoch 66: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.1667 - val_loss: 4.4596
# Epoch 67/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 67: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.1667 - val_loss: 4.4158
# Epoch 68/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0201
# Epoch 68: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.1667 - val_loss: 4.4808
# Epoch 69/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0196
# Epoch 69: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.1667 - val_loss: 4.5431
# Epoch 70/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0162
# Epoch 70: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 0.1667 - val_loss: 4.5994
# Epoch 71/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0151
# Epoch 71: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.1667 - val_loss: 4.5745
# Epoch 72/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 72: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.1667 - val_loss: 4.6572
# Epoch 73/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 73: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.1667 - val_loss: 4.6544
# Epoch 74/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 74: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.1667 - val_loss: 4.7160
# Epoch 75/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 75: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.1667 - val_loss: 4.7640
# Epoch 76/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 76: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.1667 - val_loss: 4.8377
# Epoch 77/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 77: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.1667 - val_loss: 4.8845
# Epoch 78/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 78: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.1667 - val_loss: 4.8578
# Epoch 79/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 79: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.1667 - val_loss: 4.9070
# Epoch 80/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 80: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.1667 - val_loss: 4.9610
# Epoch 81/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 81: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.1667 - val_loss: 4.9312
# Epoch 82/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 82: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.1667 - val_loss: 4.9944
# Epoch 83/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 83: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.1667 - val_loss: 5.0672
# Epoch 84/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 84: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.1667 - val_loss: 5.0418
# Epoch 85/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 85: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.1667 - val_loss: 5.0793
# Epoch 86/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 86: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.1667 - val_loss: 5.0995
# Epoch 87/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 87: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.1667 - val_loss: 5.0637
# Epoch 88/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 88: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.1667 - val_loss: 5.1616
# Epoch 89/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 89: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.1667 - val_loss: 5.1795
# Epoch 90/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 90: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.1667 - val_loss: 5.1650
# Epoch 91/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 91: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.1667 - val_loss: 5.2056
# Epoch 92/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 92: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.1667 - val_loss: 5.2672
# Epoch 93/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 93: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.1667 - val_loss: 5.2110
# Epoch 94/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 94: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.1667 - val_loss: 5.2956
# Epoch 95/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 95: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.1667 - val_loss: 5.2914
# Epoch 96/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 96: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.1667 - val_loss: 5.2883
# Epoch 97/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 97: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.1667 - val_loss: 5.3353
# Epoch 98/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 98: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.1667 - val_loss: 5.3657
# Epoch 99/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 99: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.1667 - val_loss: 5.4011
# Epoch 100/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 100: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.1667 - val_loss: 5.4493
# Epoch 101/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 101: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.1667 - val_loss: 5.4320
# Epoch 102/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 102: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.1667 - val_loss: 5.3823
# Epoch 103/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 103: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.1667 - val_loss: 5.5021
# Epoch 104/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 104: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.1667 - val_loss: 5.5018
# Epoch 105/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 105: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.1667 - val_loss: 5.5055
# Epoch 106/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 106: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.1667 - val_loss: 5.5429
# Epoch 107/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 107: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.1667 - val_loss: 5.5762
# Epoch 108/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 108: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.1667 - val_loss: 5.6045
# Epoch 109/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 109: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.1667 - val_loss: 5.5682
# Epoch 110/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 110: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.1667 - val_loss: 5.6323
# Epoch 111/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 111: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.1667 - val_loss: 5.6228
# Epoch 112/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 112: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.1667 - val_loss: 5.6053
# Epoch 113/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 113: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.1667 - val_loss: 5.6686
# Epoch 114/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 114: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.1667 - val_loss: 5.6859
# Epoch 115/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 115: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.1667 - val_loss: 5.6801
# Epoch 116/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 116: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.1667 - val_loss: 5.7183
# Epoch 117/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 117: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.1667 - val_loss: 5.7908
# Epoch 118/200
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 118: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.1667 - val_loss: 5.7455
# Epoch 119/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 119: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.1667 - val_loss: 5.8186
# Epoch 120/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 120: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.1667 - val_loss: 5.7766
# Epoch 121/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 121: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.1667 - val_loss: 5.8120
# Epoch 122/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 122: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.1667 - val_loss: 5.8099
# Epoch 123/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 123: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.1667 - val_loss: 5.8117
# Epoch 124/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 124: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.1667 - val_loss: 5.8651
# Epoch 125/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 125: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.1667 - val_loss: 5.8680
# Epoch 126/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 126: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.1667 - val_loss: 5.8706
# Epoch 127/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 127: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.1667 - val_loss: 5.8859
# Epoch 128/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 128: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.1667 - val_loss: 5.9051
# Epoch 129/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 129: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.1667 - val_loss: 5.9462
# Epoch 130/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 130: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.1667 - val_loss: 5.9328
# Epoch 131/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 131: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.1667 - val_loss: 5.9460
# Epoch 132/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 132: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.1667 - val_loss: 5.9945
# Epoch 133/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 133: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.1667 - val_loss: 6.0017
# Epoch 134/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 134: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.1667 - val_loss: 6.0099
# Epoch 135/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 135: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.1667 - val_loss: 6.0013
# Epoch 136/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 136: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1667 - val_loss: 6.0162
# Epoch 137/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 137: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1667 - val_loss: 6.0631
# Epoch 138/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 138: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1667 - val_loss: 6.1176
# Epoch 139/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 139: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.1667 - val_loss: 6.0849
# Epoch 140/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 140: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.1667 - val_loss: 6.0931
# Epoch 141/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 141: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.1667 - val_loss: 6.1026
# Epoch 142/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 142: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.1667 - val_loss: 6.1639
# Epoch 143/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 143: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.1667 - val_loss: 6.1811
# Epoch 144/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 144: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.1667 - val_loss: 6.1635
# Epoch 145/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 145: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.1667 - val_loss: 6.1860
# Epoch 146/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 146: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.1667 - val_loss: 6.1842
# Epoch 147/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 147: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.1667 - val_loss: 6.2116
# Epoch 148/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 148: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.1667 - val_loss: 6.2280
# Epoch 149/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 149: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.1667 - val_loss: 6.2426
# Epoch 150/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 150: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.1667 - val_loss: 6.2644
# Epoch 151/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 151: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.1667 - val_loss: 6.2543
# Epoch 152/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 152: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.2469
# Epoch 153/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 153: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.2825
# Epoch 154/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 154: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.3244
# Epoch 155/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 155: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.3403
# Epoch 156/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 156: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.3203
# Epoch 157/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 157: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.3588
# Epoch 158/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 158: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.3416
# Epoch 159/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 159: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1667 - val_loss: 6.3880
# Epoch 160/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 160: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.1667 - val_loss: 6.3983
# Epoch 161/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 161: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.1667 - val_loss: 6.4167
# Epoch 162/200
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 162: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.1667 - val_loss: 6.4349
# Epoch 163/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 9.9415e-04
# Epoch 163: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.1667 - val_loss: 6.4346
# Epoch 164/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 9.6628e-04
# Epoch 164: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.8155e-04 - val_accuracy: 0.1667 - val_loss: 6.4760
# Epoch 165/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.6136e-04
# Epoch 165: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.7164e-04 - val_accuracy: 0.1667 - val_loss: 6.4347
# Epoch 166/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 9.9811e-04
# Epoch 166: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.9560e-04 - val_accuracy: 0.1667 - val_loss: 6.4628
# Epoch 167/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.8995e-04
# Epoch 167: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.1322e-04 - val_accuracy: 0.1667 - val_loss: 6.4920
# Epoch 168/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 168: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.1667 - val_loss: 6.5179
# Epoch 169/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.0052e-04
# Epoch 169: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.1051e-04 - val_accuracy: 0.1667 - val_loss: 6.5149
# Epoch 170/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.9840e-04
# Epoch 170: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.0681e-04 - val_accuracy: 0.1667 - val_loss: 6.5255
# Epoch 171/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.2310e-04
# Epoch 171: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.4487e-04 - val_accuracy: 0.1667 - val_loss: 6.5318
# Epoch 172/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.5394e-04
# Epoch 172: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.6154e-04 - val_accuracy: 0.1667 - val_loss: 6.5409
# Epoch 173/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.6865e-04
# Epoch 173: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.6816e-04 - val_accuracy: 0.1667 - val_loss: 6.5627
# Epoch 174/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.5899e-04
# Epoch 174: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.6017e-04 - val_accuracy: 0.1667 - val_loss: 6.5563
# Epoch 175/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.1886e-04
# Epoch 175: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.2680e-04 - val_accuracy: 0.1667 - val_loss: 6.5943
# Epoch 176/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.0448e-04
# Epoch 176: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.0519e-04 - val_accuracy: 0.1667 - val_loss: 6.5542
# Epoch 177/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.9232e-04
# Epoch 177: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.9756e-04 - val_accuracy: 0.1667 - val_loss: 6.5719
# Epoch 178/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.5356e-04
# Epoch 178: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.3694e-04 - val_accuracy: 0.1667 - val_loss: 6.6047
# Epoch 179/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.2817e-04
# Epoch 179: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.1545e-04 - val_accuracy: 0.1667 - val_loss: 6.6125
# Epoch 180/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.5629e-04
# Epoch 180: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.5968e-04 - val_accuracy: 0.1667 - val_loss: 6.6323
# Epoch 181/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.7854e-04
# Epoch 181: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.7558e-04 - val_accuracy: 0.1667 - val_loss: 6.6613
# Epoch 182/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.1313e-04
# Epoch 182: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.1971e-04 - val_accuracy: 0.1667 - val_loss: 6.6570
# Epoch 183/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.4212e-04
# Epoch 183: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.4252e-04 - val_accuracy: 0.1667 - val_loss: 6.6815
# Epoch 184/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.2098e-04
# Epoch 184: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.1861e-04 - val_accuracy: 0.1667 - val_loss: 6.6485
# Epoch 185/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 6.7983e-04
# Epoch 185: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.8784e-04 - val_accuracy: 0.1667 - val_loss: 6.6982
# Epoch 186/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 6.6361e-04
# Epoch 186: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.7203e-04 - val_accuracy: 0.1667 - val_loss: 6.7064
# Epoch 187/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.7463e-04
# Epoch 187: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.8040e-04 - val_accuracy: 0.1667 - val_loss: 6.6868
# Epoch 188/200
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.4544e-04
# Epoch 188: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 7.3356e-04 - val_accuracy: 0.1667 - val_loss: 6.7119
# Epoch 189/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.5175e-04
# Epoch 189: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.5420e-04 - val_accuracy: 0.1667 - val_loss: 6.7417
# Epoch 190/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.4722e-04
# Epoch 190: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.5006e-04 - val_accuracy: 0.1667 - val_loss: 6.7281
# Epoch 191/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 6.7538e-04
# Epoch 191: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.6577e-04 - val_accuracy: 0.1667 - val_loss: 6.7805
# Epoch 192/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.2052e-04
# Epoch 192: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.2131e-04 - val_accuracy: 0.1667 - val_loss: 6.7668
# Epoch 193/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.0949e-04
# Epoch 193: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.1108e-04 - val_accuracy: 0.1667 - val_loss: 6.7753
# Epoch 194/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.6985e-04
# Epoch 194: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.5034e-04 - val_accuracy: 0.1667 - val_loss: 6.7938
# Epoch 195/200
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7923e-04
# Epoch 195: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 5.8151e-04 - val_accuracy: 0.1667 - val_loss: 6.8091
# Epoch 196/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.7074e-04
# Epoch 196: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7615e-04 - val_accuracy: 0.1667 - val_loss: 6.8022
# Epoch 197/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.6214e-04
# Epoch 197: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.6656e-04 - val_accuracy: 0.1667 - val_loss: 6.8333
# Epoch 198/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.6235e-04
# Epoch 198: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.6317e-04 - val_accuracy: 0.1667 - val_loss: 6.8004
# Epoch 199/200
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.7586e-04
# Epoch 199: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7153e-04 - val_accuracy: 0.1667 - val_loss: 6.8275
# Epoch 200/200
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.8070e-04
# Epoch 200: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7828e-04 - val_accuracy: 0.1667 - val_loss: 6.8630

# %%
# history = model.fit(x=x_train_ndarray, y=y_train_ndarray, epochs=100, batch_size=batch_size, verbose=1, validation_split=0.1)

# %%
model.summary()
# Out:
# Model: "mixed_lstm1d_conv_59"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg_style_cnn_59 (VGGStyleCNN)  │ ?                      │        93,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_59 (Conv1D)              │ (None, 5, 32)          │       196,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_119 (Flatten)           │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_59 (LSTM)                  │ (None, 32)             │       266,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_118 (Dropout)           │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_118 (Dense)               │ (None, 128)            │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_119 (Dropout)           │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_119 (Dense)               │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,746,068 (6.66 MB)
#  Trainable params: 582,022 (2.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,164,046 (4.44 MB)

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.figure(figsize=(5, 3))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# all use LSTM_in: overfitting, val_acc=0.33, param number=1.9m
#
# all use CONV1d_in: overfitting, val_acc=0.11, param number=67m

# %% [markdown]
# learning rate = 0.0001, batch=10, val_acc=0.3889

# %% [markdown]
# if the training is interrupted

# %% [markdown]
# SUB 5
#
# accuracy: 0.9899 - loss: 0.0952 - val_accuracy: 0.4444 - val_loss: 4.3170

# %%
model.load_weights(checkpoint_path)
model.evaluate(x=x_test_ndarray, y=y_test_ndarray, return_dict=True)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1793 - loss: 2.2754
# {'accuracy': 0.15555556118488312, 'loss': 2.243734836578369}
