# %%
# conda environment tf-gpu

# %%
from sklearn.model_selection import train_test_split
from os import listdir
from os.path import isfile, join
from scipy.io import savemat, loadmat
from sklearn.metrics import confusion_matrix

# import mat73
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns

import os
import re
import random
import einops
from scipy.io import loadmat
from pathlib import Path
from PIL import Image
# import PIL.Image as Image

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# the following import is required for matplotlib < 3.2:
from mpl_toolkits.mplot3d import Axes3D  # noqa
import matplotlib
# matplotlib.use('Agg') # use a non-interactive backend such as Agg (for PNGs), PDF, SVG or PS.

# %%
# using CNN with TensorFlow core
import tensorflow as tf
from tensorflow import keras
from keras import Model, layers, models
print("TensorFlow version:", tf.__version__)
# from tensorflow.keras import datasets, layers, models
# from tensorflow.keras.layers import Dense, Flatten, Conv2D
import matplotlib.pyplot as plt
import collections
# TensorFlow version: 2.13.0
# Out:
# TensorFlow version: 2.17.0

# %%
# tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
def get_available_device():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

# %%
print(get_available_device())
# Out:
# ['/device:CPU:0']

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # Configure video data

# %%
path = '../image dataset/'
files = os.listdir(path)
sub_num = 5
files_head = [f for f in files if re.match(r'^sub' + str(sub_num) + '.*_1\.jpg$', f)]

# %%
def get_class(fname):
  return fname.split('_')[1]

# %%
def get_sub(fname):
  return fname.split('_')[0]

# %%
def integrate_video(fname, path):
    img = Image.open(path + fname).convert('CMYK')
    data = np.expand_dims(np.asarray(img), axis=0)
    for i in range(1, 7):
        fn = fname.replace('_1.jpg',f'_{i+1}.jpg')
        img_ = Image.open(path + fn).convert('CMYK')
        arr = np.expand_dims(np.asarray(img_), axis=0)
        data = np.concatenate((data, arr), axis=0)  # shape: (frame_num, width, height, channel)
    return data

# %%
def save_video(files, path):
    ds = []
    sub_dict = []
    class_dict = []
    for f in files:
        data = integrate_video(f, path)
        sub = get_sub(f)
        cls = get_class(f)
        ds.append(data)
        sub_dict.append(sub)
        class_dict.append(cls)

    return ds, sub_dict, class_dict

# %%
data, sub_dict, class_dict = save_video(files_head, path)

# %%
data[0].shape
# Out:
# (7, 369, 433, 4)

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize

# Generate synthetic data as example (7 frames, 369x433 size, 4 channels)
original_data = data[0]

# Resize the data to (7, 32, 32, 4)
resized_data = np.zeros((7, 32, 32, 4))
for i in range(original_data.shape[0]):
    resized_data[i] = resize(original_data[i], (32, 32, 4), anti_aliasing=True)

# Plot the original and resized figure for the first frame
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Display the original frame (only first channel for visualization)
axes[0].imshow(original_data[4, :, :, :])
axes[0].set_title("Original Frame (First Channel)")
axes[0].axis('off')

# Display the resized frame (only first channel for visualization)
axes[1].imshow(resized_data[4, :, :, :])
axes[1].set_title("Resized Frame (First Channel)")
axes[1].axis('off')

plt.tight_layout()
plt.show()

def resize_image_size(data, target_size=(7, 32, 32, 4)):
    resized_data = []
    for one_video in data:
        resized_one_video = np.zeros(target_size)
        for i in range (one_video.shape[0]):
            resized_one_video[i] = resize(one_video[i], (target_size[1], target_size[2], target_size[3]), anti_aliasing=True)
        resized_data.append(resized_one_video)
    
    return resized_data

data = resize_image_size(data)

# %%
data[260].shape
# Out:
# (7, 32, 32, 4)

# %% [markdown]
# Load image: read as video frames (Tensorflow tutorial)

# %%
def get_files_per_class(files):
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %%
files_for_class = get_files_per_class(files)
classes = list(files_for_class.keys())

# %%
print('Num classes:', len(classes))
print('Num videos for class[0]:', len(files_for_class[classes[0]]))
# Out:
# Num classes: 6
# Num videos for class[0]: 2205

# %%
def select_subset_of_classes(files_for_class, classes, files_per_class):
  """ 
    Use for 3-class/in-subclass comparison
  """
  files_subset = dict()

  for class_name in classes:
    class_files = files_for_class[class_name]
    files_subset[class_name] = class_files[:files_per_class]

  return files_subset

# %%
NUM_CLASSES = 2
FILES_PER_CLASS = 90   # 270 trials for each sub, 45 trials for each class per sub, 315 trials for each class in general

# %%
files_subset = select_subset_of_classes(files_for_class, classes[:NUM_CLASSES], FILES_PER_CLASS)
list(files_subset.keys())
# Out:
# ['back', 'down']

# %%
# load data depends on subject and class

# %%
def get_files_per_sub_per_class(files):
  files_for_sub_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    sub_num = get_sub(fname)
    files_for_sub_for_class[(sub_num, class_name)].append(fname)
  return files_for_sub_for_class

# %%
files_for_sub_for_class = get_files_per_sub_per_class(files)
classes_2stage = list(files_for_sub_for_class.keys())

# %%
print('Num classes:', len(classes_2stage))
print('Num videos for class[0]:', len(files_for_sub_for_class[classes_2stage[0]]))
# Out:
# Num classes: 42
# Num videos for class[0]: 315

# %% [markdown]
# select random train/test dataset

# %%
trial_dict = {'front':0, 'back':1, 'left':2, 'right':3, 'up':4, 'down':5}
label = [trial_dict[x] for x in class_dict]

# %%
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.33, random_state=42)

# %%
print(x_train[0].shape)
print(len(x_train))
print(len(y_train))
# Out:
# (7, 32, 32, 4)
# 180
# 180

# %%
x_train = [tf.convert_to_tensor(item) for item in x_train]
x_test = [tf.convert_to_tensor(item) for item in x_test]
y_train = [tf.convert_to_tensor(item) for item in y_train]
y_test = [tf.convert_to_tensor(item) for item in y_test]

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %%
# batch_size = 8
# train_ds = train_ds.batch(batch_size)
# test_ds = test_ds.batch(batch_size)

# %%
# test_batches = tf.data.experimental.cardinality(test_ds) # return the num of test batches
# val_ds = test_ds.take(test_batches//3)
# test_ds = test_ds.skip(test_batches//3)

# %% [markdown]
# ## RCNN Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

class VGGStyleCNN(Model):
    """
    VGG-style CNN based on configuration D.
    """
    def __init__(self, img_size, n_colors):
        super(VGGStyleCNN, self).__init__()
        self.conv1 = layers.Conv2D(img_size, (3, 3), activation='relu', padding='same')
        self.conv2 = layers.Conv2D(img_size, (3, 3), activation='relu', padding='same')
        self.conv3 = layers.Conv2D(img_size, (3, 3), activation='relu', padding='same')
        self.conv4 = layers.Conv2D(img_size, (3, 3), activation='relu', padding='same')
        self.pool1 = layers.MaxPooling2D((2, 2))

        self.conv5 = layers.Conv2D(img_size * 2, (3, 3), activation='relu', padding='same')
        self.conv6 = layers.Conv2D(img_size * 2, (3, 3), activation='relu', padding='same')
        self.pool2 = layers.MaxPooling2D((2, 2))

        self.conv7 = layers.Conv2D(img_size * 4, (3, 3), activation='relu', padding='same')
        self.pool3 = layers.MaxPooling2D((2, 2))

        self.flatten = layers.Flatten()

    def call(self, inputs):
        # print(f"Input to each ConvNet: {inputs.shape}")
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.pool1(x)

        x = self.conv5(x)
        x = self.conv6(x)
        x = self.pool2(x)

        x = self.conv7(x)
        x = self.pool3(x)

        x = self.flatten(x)
        # print("ConvNet done.")
        return x


class MixedLSTM1DConv(Model):
    """
    Mixed LSTM/1D-Conv network.
    """
    def __init__(self, input_shape, n_timewin, n_classes, img_size, n_colors):
        super(MixedLSTM1DConv, self).__init__()
        self.n_timewin = n_timewin
        
        # Shared CNN
        self.cnn = VGGStyleCNN(img_size, n_colors)

        # 1D Convolution for short-term temporal patterns
        self.conv1d = layers.Conv1D(filters=64, kernel_size=3, activation='relu')
        self.flatten1d = layers.Flatten()

        # LSTM for long-term temporal dependencies
        self.lstm = layers.LSTM(units=128, activation='tanh', recurrent_activation='sigmoid')

        # Fully connected layers
        self.dropout1 = layers.Dropout(0.5)
        self.fc1 = layers.Dense(units=512, activation='relu')
        self.dropout2 = layers.Dropout(0.5)
        self.output_layer = layers.Dense(n_classes, activation='softmax')

    def call(self, inputs):
        # Process each time window frame through the shared CNN
        # print(f"Input shape: {inputs.shape}")
        cnn_outputs = [self.cnn(inputs[:, i, :, :, :]) for i in range(self.n_timewin)]
        # print(f"Shape after ConvNet: {len(cnn_outputs)}*{cnn_outputs[0].shape}")

        # Reshape the sequence
        lstm_in = tf.stack(cnn_outputs, axis=1)  # now: (batch_size, n_timewin, features)
        # conv1d_in = tf.transpose(lstm_in, perm=[0, 2, 1]) # should be (batch_size, features, n_timewin)
        # print(f"Reshaped to feed Conv1D: {conv1d_in.shape}")
        # print(f"Reshaped to feed LSTM: {lstm_in.shape}")

        # 1D Convolution for temporal patterns
        conv1d_out = self.conv1d(lstm_in)
        # print(f"Shape after Conv1D: {conv1d_out.shape}")
        conv1d_out = self.flatten1d(conv1d_out)
        # print(f"Flattened to combine with LSTM: {conv1d_out.shape}")
        # LSTM for long-term dependencies
        lstm_out = self.lstm(lstm_in)
        # print(f"Shape after LSTM: {lstm_out.shape}")

        # Merge 1D-Conv and LSTM outputs
        merged = tf.concat([conv1d_out, lstm_out], axis=-1)
        # print(f"Merged to feed FC: {merged.shape}")
        # Fully connected layers
        x = self.dropout1(merged)
        x = self.fc1(x)
        x = self.dropout2(x)
        output = self.output_layer(x)
        # print(f"Output shape: {output.shape}")
        return output


# Example usage
batch_size = 10
input_shape = (batch_size, 7, 32, 32, 4)
n_timewin = 7
n_classes = 6
img_size = 32
n_colors = 4

# Create the model instance
model = MixedLSTM1DConv(input_shape, n_timewin, n_classes, img_size, n_colors)

# model.summary()

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), # default lr=0.0001 
              metrics = ['accuracy'])

# %%
x_train_tmp = [tensor.numpy() for tensor in x_train]
x_train_ndarray = np.stack(x_train_tmp, axis=0)
print(x_train_ndarray.shape)
y_train_ndarray = np.array([tensor.numpy() for tensor in y_train])

x_test_tmp = [tensor.numpy() for tensor in x_test]
x_test_ndarray = np.stack(x_test_tmp, axis=0)
print(x_test_ndarray.shape)
y_test_ndarray = np.array([tensor.numpy() for tensor in y_test])
# Out:
# (180, 7, 32, 32, 4)
# (90, 7, 32, 32, 4)

# %%
# checkpoint_path = "./sub5_training_stride1_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)
checkpoint_path = "./rcnn/sub"+str(sub_num)+"_training/cp.weights.h5"  # Change the file extension
# checkpoint_dir = os.path.dirname(checkpoint_path)
os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True, # save the entire model or weights only
                                                 verbose=1,
                                                 monitor='val_accuracy',
                                                 mode='max',  # max for acc, min for loss
                                                 save_best_only=True)

history = model.fit(x=x_train_ndarray, y=y_train_ndarray, epochs=60, batch_size=batch_size, verbose=1, validation_split=0.1, callbacks=[cp_callback])

# history = model.fit(x = train_ds,
#                     epochs = 60,
#                     validation_data = val_ds,
#                     callbacks=[cp_callback])
# Out:
# Epoch 1/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1463 - loss: 1.7956
# Epoch 1: val_accuracy improved from -inf to 0.16667, saving model to ./rcnn/sub5_training/cp.weights.h5
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.1457 - loss: 1.7957 - val_accuracy: 0.1667 - val_loss: 1.7969
# Epoch 2/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1346 - loss: 1.7900
# Epoch 2: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.1353 - loss: 1.7900 - val_accuracy: 0.1111 - val_loss: 1.8165
# Epoch 3/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2398 - loss: 1.7782
# Epoch 3: val_accuracy did not improve from 0.16667
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.2365 - loss: 1.7787 - val_accuracy: 0.0556 - val_loss: 1.8531
# Epoch 4/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2151 - loss: 1.7882
# Epoch 4: val_accuracy improved from 0.16667 to 0.22222, saving model to ./rcnn/sub5_training/cp.weights.h5
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2169 - loss: 1.7876 - val_accuracy: 0.2222 - val_loss: 1.8620
# Epoch 5/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2446 - loss: 1.7654
# Epoch 5: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.2423 - loss: 1.7662 - val_accuracy: 0.0556 - val_loss: 1.8729
# Epoch 6/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2585 - loss: 1.7884
# Epoch 6: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.2592 - loss: 1.7878 - val_accuracy: 0.0556 - val_loss: 1.8368
# Epoch 7/60
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3098 - loss: 1.7739
# Epoch 7: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.3145 - loss: 1.7729 - val_accuracy: 0.1111 - val_loss: 1.8882
# Epoch 8/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3295 - loss: 1.7439
# Epoch 8: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.3284 - loss: 1.7439 - val_accuracy: 0.0556 - val_loss: 1.9352
# Epoch 9/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3399 - loss: 1.7130
# Epoch 9: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.3354 - loss: 1.7142 - val_accuracy: 0.0556 - val_loss: 2.0150
# Epoch 10/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3305 - loss: 1.6623
# Epoch 10: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3307 - loss: 1.6636 - val_accuracy: 0.1111 - val_loss: 2.0906
# Epoch 11/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.3558 - loss: 1.6464
# Epoch 11: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.3542 - loss: 1.6475 - val_accuracy: 0.0556 - val_loss: 2.1490
# Epoch 12/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2690 - loss: 1.6809
# Epoch 12: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.2705 - loss: 1.6813 - val_accuracy: 0.1111 - val_loss: 1.9306
# Epoch 13/60
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4377 - loss: 1.5736
# Epoch 13: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.4330 - loss: 1.5727 - val_accuracy: 0.1111 - val_loss: 2.2524
# Epoch 14/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4606 - loss: 1.4560
# Epoch 14: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4562 - loss: 1.4606 - val_accuracy: 0.1111 - val_loss: 2.2730
# Epoch 15/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4471 - loss: 1.4876
# Epoch 15: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4480 - loss: 1.4862 - val_accuracy: 0.0556 - val_loss: 2.3192
# Epoch 16/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5303 - loss: 1.2903
# Epoch 16: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5269 - loss: 1.2948 - val_accuracy: 0.1667 - val_loss: 2.5015
# Epoch 17/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4471 - loss: 1.3137
# Epoch 17: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4491 - loss: 1.3135 - val_accuracy: 0.1667 - val_loss: 2.4572
# Epoch 18/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6017 - loss: 1.1099
# Epoch 18: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6026 - loss: 1.1091 - val_accuracy: 0.1111 - val_loss: 2.8588
# Epoch 19/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6660 - loss: 0.8637
# Epoch 19: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6660 - loss: 0.8681 - val_accuracy: 0.1111 - val_loss: 3.1482
# Epoch 20/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7264 - loss: 0.7924
# Epoch 20: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7262 - loss: 0.7938 - val_accuracy: 0.1111 - val_loss: 3.2240
# Epoch 21/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8335 - loss: 0.6176
# Epoch 21: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8311 - loss: 0.6191 - val_accuracy: 0.1111 - val_loss: 3.3958
# Epoch 22/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8813 - loss: 0.4542
# Epoch 22: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8824 - loss: 0.4532 - val_accuracy: 0.0556 - val_loss: 4.4796
# Epoch 23/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9065 - loss: 0.2905
# Epoch 23: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9066 - loss: 0.2911 - val_accuracy: 0.1667 - val_loss: 4.2048
# Epoch 24/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9762 - loss: 0.1804
# Epoch 24: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9758 - loss: 0.1807 - val_accuracy: 0.1111 - val_loss: 4.7557
# Epoch 25/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9769 - loss: 0.1131
# Epoch 25: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9765 - loss: 0.1139 - val_accuracy: 0.2222 - val_loss: 5.1034
# Epoch 26/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9993 - loss: 0.0790
# Epoch 26: val_accuracy did not improve from 0.22222
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9990 - loss: 0.0789 - val_accuracy: 0.1667 - val_loss: 6.5389
# Epoch 27/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9818 - loss: 0.0807
# Epoch 27: val_accuracy improved from 0.22222 to 0.27778, saving model to ./rcnn/sub5_training/cp.weights.h5
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9821 - loss: 0.0804 - val_accuracy: 0.2778 - val_loss: 6.0670
# Epoch 28/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0397
# Epoch 28: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0393 - val_accuracy: 0.1111 - val_loss: 6.2463
# Epoch 29/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 29: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.1111 - val_loss: 6.5954
# Epoch 30/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 30: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.1667 - val_loss: 6.6496
# Epoch 31/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 31: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.1667 - val_loss: 6.8271
# Epoch 32/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 32: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.1667 - val_loss: 6.9343
# Epoch 33/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 33: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.1667 - val_loss: 7.0960
# Epoch 34/60
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 34: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.1667 - val_loss: 7.1827
# Epoch 35/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 35: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1667 - val_loss: 7.2529
# Epoch 36/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 36: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.1667 - val_loss: 7.4390
# Epoch 37/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 37: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.2222 - val_loss: 7.5674
# Epoch 38/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 38: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2222 - val_loss: 7.6489
# Epoch 39/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 39: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2222 - val_loss: 7.7077
# Epoch 40/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 8.1112e-04
# Epoch 40: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 8.2494e-04 - val_accuracy: 0.2222 - val_loss: 7.7560
# Epoch 41/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 41: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2222 - val_loss: 7.8806
# Epoch 42/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 9.7514e-04
# Epoch 42: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 9.7128e-04 - val_accuracy: 0.2222 - val_loss: 7.9420
# Epoch 43/60
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 8.2002e-04
# Epoch 43: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 8.2220e-04 - val_accuracy: 0.2222 - val_loss: 7.9924
# Epoch 44/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 8.1849e-04
# Epoch 44: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 8.1642e-04 - val_accuracy: 0.2222 - val_loss: 8.0346
# Epoch 45/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 7.6045e-04
# Epoch 45: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 7.5885e-04 - val_accuracy: 0.2222 - val_loss: 8.0767
# Epoch 46/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 6.7337e-04
# Epoch 46: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 6.7381e-04 - val_accuracy: 0.2222 - val_loss: 8.1338
# Epoch 47/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 6.6468e-04
# Epoch 47: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 6.6362e-04 - val_accuracy: 0.2222 - val_loss: 8.1824
# Epoch 48/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 5.9176e-04
# Epoch 48: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 5.9258e-04 - val_accuracy: 0.2222 - val_loss: 8.2431
# Epoch 49/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 5.3273e-04
# Epoch 49: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 5.3476e-04 - val_accuracy: 0.2222 - val_loss: 8.2998
# Epoch 50/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 5.4801e-04
# Epoch 50: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 5.4743e-04 - val_accuracy: 0.2222 - val_loss: 8.3371
# Epoch 51/60
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 5.7597e-04
# Epoch 51: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 5.6858e-04 - val_accuracy: 0.2222 - val_loss: 8.3797
# Epoch 52/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 5.0598e-04
# Epoch 52: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 5.0492e-04 - val_accuracy: 0.2222 - val_loss: 8.4336
# Epoch 53/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 5.3913e-04
# Epoch 53: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 5.3477e-04 - val_accuracy: 0.2222 - val_loss: 8.4815
# Epoch 54/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 4.5484e-04
# Epoch 54: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 4.5367e-04 - val_accuracy: 0.2222 - val_loss: 8.5309
# Epoch 55/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 4.0092e-04
# Epoch 55: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 4.0160e-04 - val_accuracy: 0.2222 - val_loss: 8.5995
# Epoch 56/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 4.0745e-04
# Epoch 56: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 4.0671e-04 - val_accuracy: 0.2222 - val_loss: 8.6427
# Epoch 57/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 3.6860e-04
# Epoch 57: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 3.6915e-04 - val_accuracy: 0.2222 - val_loss: 8.6669
# Epoch 58/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 3.4681e-04
# Epoch 58: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 3.4741e-04 - val_accuracy: 0.2222 - val_loss: 8.6829
# Epoch 59/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 3.1049e-04
# Epoch 59: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 3.1227e-04 - val_accuracy: 0.2222 - val_loss: 8.7039
# Epoch 60/60
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 3.4715e-04
# Epoch 60: val_accuracy did not improve from 0.27778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 3.4603e-04 - val_accuracy: 0.2222 - val_loss: 8.7638

# %%
# history = model.fit(x=x_train_ndarray, y=y_train_ndarray, epochs=100, batch_size=batch_size, verbose=1, validation_split=0.1)

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.figure(figsize=(5, 3))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "mixed_lstm1d_conv_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg_style_cnn_31 (VGGStyleCNN)  │ ?                      │       158,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_31 (Conv1D)              │ (None, 5, 64)          │       393,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_63 (Flatten)            │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_31 (LSTM)                  │ (None, 128)            │     1,114,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_62 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 512)            │       229,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_63 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,697,236 (21.73 MB)
#  Trainable params: 1,899,078 (7.24 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,798,158 (14.49 MB)

# %% [markdown]
# all use LSTM_in: overfitting, val_acc=0.33, param number=1.9m
#
# all use CONV1d_in: overfitting, val_acc=0.11, param number=67m

# %% [markdown]
# if the training is interrupted

# %% [markdown]
# SUB 5
#
# accuracy: 0.9899 - loss: 0.0952 - val_accuracy: 0.4444 - val_loss: 4.3170

# %%
# # if the training is interrupted
# model.load_weights('./sub1_training_stride1_2/cp.ckpt')
# # model.load_weights(checkpoint_path)
# history = model.fit(x = train_ds,
#                     epochs = 30, 
#                     validation_data = val_ds,
#                     callbacks=[cp_callback])

# %%
# stride1
# sub1
# train acc: 65.56%; val acc: 31.25%; test acc: 27.59%   # sub1 train0
# train acc: 57.22%; val acc：34.375%； test acc: 22.41%   # sub1 train1
# train acc: 78.33%; val acc: 31.25%; test acc: 24.14%   # sub1 train2
# train acc: 50.56%; val acc: 28.125%; test acc: 29.31% # sub1 train3

# sub2
# train acc: 72.78%; val acc: 34.375%; test acc: 44.828% # sub2 train0
# train acc: 69.44%; val acc: 37.50%; test acc: 37.93% # sub2 train1
# train acc: 71.67%; val acc: 43.75%; test acc: 41.38% # sub2 train2
# train acc: 91.67%; val acc: 50.00%; test acc: 39.66% # sub2 train3 (additional training from train2 model)
# train acc: 73.33%; val acc: 37.50%; test acc: 48.28% # sub2 train4 (additional training from train0 model)

# sub3
# train acc: 41.11%; val acc: 34.375%; test acc: 24.14% # sub3 train0

# sub5
# train acc: 73.89%; val acc: 34.375%; test acc: 25.86% # sub5 train0

# sub7
# train acc: 66.11%; val acc: 31.25%; test acc: 25.86% # sub7 train0

# %% [markdown]
# ### Load weight and test

# %%
# model.load_weights('./sub5_training_stride1_1/cp.ckpt')
# model.evaluate(val_ds, return_dict=True)

# %%
model.load_weights(checkpoint_path)
model.evaluate(x=x_test_ndarray, y=y_test_ndarray, return_dict=True)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1024 - loss: 6.9164
# {'accuracy': 0.1111111119389534, 'loss': 6.633885860443115}
